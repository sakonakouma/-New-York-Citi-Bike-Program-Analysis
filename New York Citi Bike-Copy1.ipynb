# %%
#import dependecies 
import pandas as pd
import numpy as np

# %%
Oct19_data="201910-citibike-tripdata.csv"
Oct19_data=pd.read_csv(Oct19_data)
Oct19_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1           174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2           759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3           615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4           761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
#
#    start station id      start station name  start station latitude  \
# 0              3746       6 Ave & Broome St               40.724308
# 1              3301  Columbus Ave & W 95 St               40.791956
# 2               161   LaGuardia Pl & W 3 St               40.729170
# 3               254         W 11 St & 6 Ave               40.735324
# 4               161   LaGuardia Pl & W 3 St               40.729170
#
#    start station longitude  end station id        end station name  \
# 0               -74.004730             223         W 13 St & 7 Ave
# ...

# %%
Nov19_data="201911-citibike-tripdata.csv"
Nov19_data=pd.read_csv(Nov19_data)
Nov19_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           273  2019-11-01 00:00:00.2930  2019-11-01 00:04:34.1880
# 1           159  2019-11-01 00:00:03.5840  2019-11-01 00:02:43.4780
# 2           967  2019-11-01 00:00:06.2670  2019-11-01 00:16:14.0990
# 3           604  2019-11-01 00:00:21.7610  2019-11-01 00:10:25.8910
# 4           153  2019-11-01 00:00:25.2060  2019-11-01 00:02:59.0180
#
#    start station id     start station name  start station latitude  \
# 0               237        E 11 St & 2 Ave               40.730473
# 1              3572         34 Ave & 38 St               40.756913
# 2               334        W 20 St & 7 Ave               40.742388
# 3               280        E 10 St & 5 Ave               40.733320
# 4              3761  Cedar St & Myrtle Ave               40.697842
#
#    start station longitude  end station id          end station name  \
# 0               -73.986724             335  Washington Pl & Broadway
# ...

# %%
Dec19_data="201912-citibike-tripdata.csv"
Dec19_data=pd.read_csv(Dec19_data)
Dec19_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1          1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2           723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3           404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4          1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
#
#    start station id      start station name  start station latitude  \
# 0              3382   Carroll St & Smith St               40.680611
# 1               362      Broadway & W 37 St               40.751726
# 2               146    Hudson St & Reade St               40.716250
# 3              3834  Irving Ave & Halsey St               40.694670
# 4               500      Broadway & W 51 St               40.762288
#
#    start station longitude  end station id              end station name  \
# ...

# %%
Data_all0=pd.concat([Oct19_data, Nov19_data, Dec19_data], ignore_index=True)
Data_all0.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1           174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2           759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3           615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4           761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
#
#    start station id      start station name  start station latitude  \
# 0              3746       6 Ave & Broome St               40.724308
# 1              3301  Columbus Ave & W 95 St               40.791956
# 2               161   LaGuardia Pl & W 3 St               40.729170
# 3               254         W 11 St & 6 Ave               40.735324
# 4               161   LaGuardia Pl & W 3 St               40.729170
#
#    start station longitude  end station id        end station name  \
# 0               -74.004730             223         W 13 St & 7 Ave
# ...

# %%
Data_all0.sort_values(by=['starttime'], inplace=True, ascending=True)
Data_all0
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                 174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                 759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                 615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                 761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...               ...                       ...                       ...
# 4526486            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 4526487           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 4526488           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 4526489          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 4526490           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#          start station id                start station name  \
# ...

# %%
# Splitting the column 'title' into two columns 'Title' and 'Release Year'
STARTDAY= Data_all0["starttime"].str.rsplit(" ", n = 1, expand = True)
Data_all0["startday"] = STARTDAY[0]
Data_all0["starttime"] = STARTDAY[1]

STARTDAY2= Data_all0["starttime"].str.rsplit(".", n = 1, expand = True)
Data_all0["starttime"] = STARTDAY2[0]
Data_all0.head()

# %%
Data_all0.dropna()
Data_all0[Data_all0.gender!=0]

# %%
Data_all0["age"]=2020-Data_all0["birth year"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb5da19005f2> in <module>
# ----> 1 Data_all0["age"]=2020-Data_all0["birth year"]
#
# NameError: name 'Data_all0' is not defined

# %%
Data_all0.loc[Data_all0["age"]<100]
Data_all0
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-db0eb851fddc> in <module>
# ----> 1 Data_all0.loc[Data_all0["age"]<100]
#       2 Data_all0
#
# ~\anaconda3.1\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3.1\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911             return self._get_slice_axis(key, axis=axis)
#    1912         elif com.is_bool_indexer(key):
# -> 1913             return self._getbool_axis(key, axis=axis)
#    1914         elif is_list_like_indexer(key):
#    1915
#
# ...

# %%
all0.to_csv("Data_2019.csv")

# %%
Jan20_data="202001-citibike-tripdata.csv"
Jan20_data=pd.read_csv(Jan20_data)
Jan20_data.head()

# %%
Feb20_data="202002-citibike-tripdata.csv"
Feb20_data=pd.read_csv(Feb20_data)
Feb20_data.head()

# %%
Mars20_data="202003-citibike-tripdata.csv"
Mars20_data=pd.read_csv(Mars20_data)
Mars20_data.head()

# %%
Apr20_data="202004-citibike-tripdata.csv"
Apr20_data=pd.read_csv(Apr20_data)
Apr20_data.head()

# %%
May20_data="202005-citibike-tripdata.csv"
May20_data=pd.read_csv(May20_data)
May20_data.head()

# %%
Jun20_data="202006-citibike-tripdata.csv"
Jun20_data=pd.read_csv(Jun20_data)
Jun20_data.head()

# %%
Jul20_data="202007-citibike-tripdata.csv"
Jul20_data=pd.read_csv(Jul20_data)
Jul20_data.head()

# %%
Aug20_data="202008-citibike-tripdata.csv"
Aug20_data=pd.read_csv(Aug20_data)
Aug20_data.head()

# %%
Data_all=pd.concat([Jun20_data, Jul20_data, Aug20_data], ignore_index=True)
Data_all.head()

# %%
# Splitting the column 'title' into two columns 'Title' and 'Release Year'
STARTDAY= Data_all["starttime"].str.rsplit(" ", n = 1, expand = True)
Data_all["startday"] = STARTDAY[0]
Data_all["starttime"] = STARTDAY[1]

STARTDAY2= Data_all["starttime"].str.rsplit(".", n = 1, expand = True)
Data_all["starttime"] = STARTDAY2[0]
Data_all.head()

# %%
Data_all.dropna()
Data_all[Data_all.gender!=0]

# %%
Data_all["age"]=2020-Data_all["birth year"]

# %%
Data_all.loc[Data_all["age"]>100]
Data_all

# %%
Data_all.to_csv("Final_dataDef1.csv", encoding='utf-8', index=False)

# %%
Data2019_20=pd.concat([Data_all, Data_all0], ignore_index=True)
Data2019_20

# %%
#Data2019_20.to_csv("Final_data2019_20.csv", encoding='utf-8', index=False)

# %%
Data2019_20.sort_values(by=['starday'], inplace=true, ascending=true)
